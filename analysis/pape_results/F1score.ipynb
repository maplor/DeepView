# %%
import pickle
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from deepview.calculate_results.models.utils import (
labeldict_findstr,
majority_value,
    labeldict_findstr,
)
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# %%
root_path = r'D:\code\DeepView\deepview\calculate_results\data\umineko'

# %%
def load_data(file_name):
    with open(os.path.join(root_path, file_name), 'rb') as f:
        data = pickle.load(f)
    return data

# %% [markdown]
# # 几种active learning方法的F1 score对比

# %%
# active learning采用random sampling方法
file_name = 'AccelTemp__random_Contrast1_warm20_epoch20_results.pkl'  
result_dict = load_data(file_name)
base_acc = result_dict['test_micro_f1_list']
base_pred_label_lists = result_dict['test_pred_label_lists']
base_true_label_lists = result_dict['test_truth_label_lists']
base_selected_labels_list = result_dict['selected_labels_list']
base_ari_list = result_dict['ari_list']
base_nmi_list = result_dict['nmi_list']
base_fmi_list = result_dict['fmi_list']
base_silhouette_list = result_dict['silhouette_list']
base_label_data_list = result_dict['label_data_list']
base_unlabel_data_list = result_dict['unlabel_data_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict = load_data(file_name)
entropy_acc = result_dict['test_micro_f1_list']
entropy_pred_label_lists = result_dict['test_pred_label_lists']
entropy_true_label_lists = result_dict['test_truth_label_lists']
entropy_selected_labels_list = result_dict['selected_labels_list']
entropy_ari_list = result_dict['ari_list']
entropy_nmi_list = result_dict['nmi_list']
entropy_fmi_list = result_dict['fmi_list']
entropy_silhouette_list = result_dict['silhouette_list']
entropy_label_data_list = result_dict['label_data_list']
entropy_unlabel_data_list = result_dict['unlabel_data_list']

file_name = 'AccelTemp__underRandom_Contrast1_warm20_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict = load_data(file_name)
under_acc = result_dict['test_micro_f1_list']
under_pred_label_lists = result_dict['test_pred_label_lists']
under_true_label_lists = result_dict['test_truth_label_lists']
under_selected_labels_list = result_dict['selected_labels_list']
under_ari_list = result_dict['ari_list']
under_nmi_list = result_dict['nmi_list']
under_fmi_list = result_dict['fmi_list']
under_silhouette_list = result_dict['silhouette_list']
under_label_data_list = result_dict['label_data_list']
under_unlabel_data_list = result_dict['unlabel_data_list']

file_name = 'AccelTemp__overAugment_Contrast1_warm20_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict = load_data(file_name)
over_acc = result_dict['test_micro_f1_list']
over_pred_label_lists = result_dict['test_pred_label_lists']
over_true_label_lists = result_dict['test_truth_label_lists']
over_selected_labels_list = result_dict['selected_labels_list']
over_ari_list = result_dict['ari_list']
over_nmi_list = result_dict['nmi_list']
over_fmi_list = result_dict['fmi_list']
over_silhouette_list = result_dict['silhouette_list']
over_label_data_list = result_dict['label_data_list']
over_unlabel_data_list = result_dict['unlabel_data_list']

file_name = 'AccelTemp__supervisebase_epoch20_results.pkl'  # supervised learning baseline
result_dict = load_data(file_name)
supervise_acc = result_dict['test_micro_f1_list']
supervise_pred_label_lists = result_dict['test_pred_label_lists']
supervise_true_label_lists = result_dict['test_truth_label_lists']
supervise_selected_labels_list = result_dict['selected_labels_list']
supervise_ari_list = result_dict['ari_list']
supervise_nmi_list = result_dict['nmi_list']
supervise_fmi_list = result_dict['fmi_list']
supervise_silhouette_list = result_dict['silhouette_list']
# supervise_label_data_list = result_dict['label_data_list']
# supervise_unlabel_data_list = result_dict['unlabel_data_list']
# iterations = list(range(1, len(base_acc) + 1))
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
file_name = 'AccelTemp__entropy_Contrast1_warm20_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict = load_data(file_name)
entropy_acc = result_dict['test_micro_f1_list']
print(entropy_acc[-1])
entropy_ari_list = result_dict['ari_list']
entropy_nmi_list = result_dict['nmi_list']
entropy_fmi_list = result_dict['fmi_list']
entropy_silhouette_list = result_dict['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed5_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict5 = load_data(file_name)
entropy_acc5 = result_dict5['test_micro_f1_list']
print(entropy_acc5[-1])
entropy_ari_list5 = result_dict5['ari_list']
entropy_nmi_list5 = result_dict5['nmi_list']
entropy_fmi_list5 = result_dict5['fmi_list']
entropy_silhouette_list5 = result_dict5['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed2_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict2 = load_data(file_name)
entropy_acc2 = result_dict2['test_micro_f1_list']
print(entropy_acc2[-1])
entropy_ari_list2 = result_dict2['ari_list']
entropy_nmi_list2 = result_dict2['nmi_list']
entropy_fmi_list2 = result_dict2['fmi_list']
entropy_silhouette_list2 = result_dict2['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed1_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict1 = load_data(file_name)
entropy_acc1 = result_dict1['test_micro_f1_list']
print(entropy_acc1[-1])
entropy_ari_list1 = result_dict1['ari_list']
entropy_nmi_list1 = result_dict1['nmi_list']
entropy_fmi_list1 = result_dict1['fmi_list']
entropy_silhouette_list1 = result_dict1['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed10_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict10 = load_data(file_name)
entropy_acc10 = result_dict10['test_micro_f1_list']
print(entropy_acc10[-1])

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed2025_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict2025 = load_data(file_name)
entropy_acc2025 = result_dict2025['test_micro_f1_list']
print(entropy_acc2025[-1])
entropy_ari_list2025 = result_dict2025['ari_list']
entropy_nmi_list2025 = result_dict2025['nmi_list']
entropy_fmi_list2025 = result_dict2025['fmi_list']
entropy_silhouette_list2025 = result_dict2025['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm20_seed50_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict50 = load_data(file_name)
entropy_acc50 = result_dict50['test_micro_f1_list']
print(entropy_acc50[-1])
# Out:
# 0.9373315363881402
# 0.938047138047138
# 0.9313593539703903
# 0.9339622641509434
# 0.9333781965006729
# 0.9259259259259259
# 0.9245791245791246

# %%
# 完全不使用contrastive learning的entropy active learning
file_name = 'AccelTemp__entropy_Contrast1_warm0_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict = load_data(file_name)
entropy_acc_wocontrast = result_dict['test_micro_f1_list']
print(entropy_acc_wocontrast[-1])
entropy_wocont_ari_list = result_dict['ari_list']
entropy_wocont_nmi_list = result_dict['nmi_list']
entropy_wocont_fmi_list = result_dict['fmi_list']
entropy_wocont_silhouette_list = result_dict['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed10_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict10 = load_data(file_name)
entropy_acc_wocontrast10 = result_dict10['test_micro_f1_list']
print(entropy_acc_wocontrast10[-1])
entropy_wocont_ari_list10 = result_dict10['ari_list']
entropy_wocont_nmi_list10 = result_dict10['nmi_list']
entropy_wocont_fmi_list10 = result_dict10['fmi_list']
entropy_wocont_silhouette_list10 = result_dict10['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed5_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict5 = load_data(file_name)
entropy_acc_wocontrast5 = result_dict5['test_micro_f1_list']
print(entropy_acc_wocontrast5[-1])
entropy_wocont_ari_list5 = result_dict5['ari_list']
entropy_wocont_nmi_list5 = result_dict5['nmi_list']
entropy_wocont_fmi_list5 = result_dict5['fmi_list']
entropy_wocont_silhouette_list5 = result_dict5['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed50_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict50 = load_data(file_name)
entropy_acc_wocontrast50 = result_dict50['test_micro_f1_list']
print(entropy_acc_wocontrast50[-1])
entropy_wocont_ari_list50 = result_dict50['ari_list']
entropy_wocont_nmi_list50 = result_dict50['nmi_list']
entropy_wocont_fmi_list50 = result_dict50['fmi_list']
entropy_wocont_silhouette_list50 = result_dict50['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed2_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict2 = load_data(file_name)
entropy_acc_wocontrast2 = result_dict2['test_micro_f1_list']
print(entropy_acc_wocontrast2[-1])

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed100_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict100 = load_data(file_name)
entropy_acc_wocontrast100 = result_dict100['test_micro_f1_list']
print(entropy_acc_wocontrast100[-1])
entropy_wocont_ari_list100 = result_dict100['ari_list']
entropy_wocont_nmi_list100 = result_dict100['nmi_list']
entropy_wocont_fmi_list100 = result_dict100['fmi_list']
entropy_wocont_silhouette_list100 = result_dict100['silhouette_list']

file_name = 'AccelTemp__entropy_Contrast1_warm0_seed500_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict500 = load_data(file_name)
entropy_acc_wocontrast500 = result_dict500['test_micro_f1_list']
print(entropy_acc_wocontrast500[-1])
# Out:
# 0.9394347240915208
# 0.905971173644475
# 0.938047138047138
# 0.9454912516823688
# 0.9414535666218035
# 0.9347240915208613
# 0.9373737373737374

# %%
num_iterations = 20
num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 1:
            # f1 = base_acc[i]
            f1 = entropy_acc_wocontrast[i]
            f2 = entropy_acc_wocontrast10[i]
            f3 = entropy_acc_wocontrast5[i]
            f4 = entropy_acc_wocontrast50[i]
            # f5 = entropy_acc_wocontrast2[i]
            f6 = entropy_acc_wocontrast100[i]
            # f7 = entropy_acc_wocontrast500[i]
            avg_f = np.average([f1,f2,f3,f4,f6])
            sem_f = np.std([f1,f2,f3,f4,f6]) / np.sqrt(7 + 1e-9)
        else:
            f1 = entropy_acc[i]
            f2 = entropy_acc5[i]
            f3 = entropy_acc2[i]
            f4 = entropy_acc1[i]
            # f5 = entropy_acc10[i]
            f6 = entropy_acc10[i]
            avg_f = np.average([f1,f2,f3,f4,f6])
            sem_f = np.std([f1,f2,f3,f4,f6]) / np.sqrt(7 + 1e-9)
        f1_scores[cls].append(avg_f*100)
        std_devs[cls].append(sem_f*100)

# # 计算标准误差（SEM）
# std_devs = {cls: np.std(f1_scores[cls]) / np.sqrt(len(f1_scores[cls]) + 1e-9) for cls in f1_scores}

# 画图
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
# fig, ax = plt.subplots(figsize=(5, 8), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
}

labels = {0: 'Entropy-based Active Learning', 
          1: 'Entropy Active W/O Contrastive Learning', 
          2: 'OverSampling Active', 
          3: 'Entropy Active',
          4: 'Supervised Baseline'}

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls], 
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)
    
    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1), 
                    np.array(f1_scores[cls]) - std_devs[cls], 
                    np.array(f1_scores[cls]) + std_devs[cls], 
                    color=colors[cls], alpha=0.1)

# 标注轴标签
ax.set_xlabel("Iteration", fontsize=14)
ax.set_ylabel("F1 Score (%)", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签


# 添加每个类别的虚线
ax.axhline(y=supervise_acc[-1]*100, 
           color='grey', linestyle="--", label=labels[4], linewidth=1.5)

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
ax.set_ylim(75, 95)
# 添加图例
ax.legend(frameon=False)

# 保存高清图片
output_path_lines = "F1_contrastlearning_iter20.png"
plt.savefig(output_path_lines, bbox_inches="tight", dpi=300)

# 显示图表
plt.show()

# %%
file_name = 'AccelTemp__entropy_Contrast1_warm20_seed5_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict5 = load_data(file_name)
# entropy_acc5 = result_dict5['test_micro_f1_list']
# print(entropy_acc5[-1])
pred_label_lists = result_dict5['test_pred_label_lists']
true_label_lists = result_dict5['test_truth_label_lists']
cm = confusion_matrix(true_label_lists[-10], pred_label_lists[-10], labels=list(labeldict_findstr.keys()))
print(cm)
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# ...

# %%
file_name = 'AccelTemp__entropy_Contrast1_warm0_seed10_epoch20_results.pkl'  # noSupCont, only entropy active learning
result_dict10 = load_data(file_name)
# entropy_acc_wocontrast = result_dict['test_micro_f1_list']
pred_label_lists = result_dict10['test_pred_label_lists']
true_label_lists = result_dict10['test_truth_label_lists']
cm = confusion_matrix(true_label_lists[-10], pred_label_lists[-10], labels=list(labeldict_findstr.keys()))
print(cm)
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# ...

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# 生成随机的 F1 scores
categories = ['Random Sampling', 'Under Sampling', 'Over Sampling', 'Entropy Sampling']
f1_scores = [base_acc[-1]*100, under_acc[-1]*100, over_acc[-1]*100, entropy_acc[-1]*100]

# 设置颜色
colors = ['black', 'purple', 'darkred', 'magenta']

# 创建画布，调整风格以符合 Nature 期刊审美
plt.figure(figsize=(6, 4), dpi=300)
# plt.style.use('seaborn-white')

# 绘制散点图
plt.scatter(categories, f1_scores, color=colors, s=150, edgecolors='black', alpha=0.9, linewidth=1.2)

# # 添加参考虚线（均值 F1 score）
# avg_f1 = np.mean(f1_scores)
# plt.axhline(y=avg_f1, color='green', linestyle='dotted', linewidth=1.5, alpha=0.8)

# 设置标题和标签
plt.ylabel("Micro F1 score", fontsize=12, fontweight='bold')
plt.ylim(80, 100)
# plt.xticks(fontsize=11, fontweight='bold')
plt.xticks(fontsize=11, fontweight='bold', rotation=45)
plt.yticks(fontsize=11, fontweight='bold')
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.6)

# 移除顶部和右侧边框，使其更简洁
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_linewidth(1.2)
plt.gca().spines['bottom'].set_linewidth(1.2)

# 保存图片
plt.savefig("f1_score_plot.png", bbox_inches='tight', dpi=300)

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# 重新生成数据
# np.random.seed(42)
num_iterations = 20
num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1, 2, 3]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            f1 = base_acc[i]
        elif cls == 1:
            f1 = under_acc[i]
        elif cls == 2:
            f1 = over_acc[i]
        else:
            f1 = entropy_acc[i]
        f1_scores[cls].append(f1*100)

# 计算标准误差（SEM）
std_devs = {cls: np.std(f1_scores[cls]) / np.sqrt(len(f1_scores[cls]) + 1e-9) for cls in f1_scores}

# 画图
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
}

labels = {0: 'Random Active', 
          1: 'UnderSampling Active', 
          2: 'OverSampling Active', 
          3: 'Entropy Active',
          4: 'Supervised Baseline'}

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls], 
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)
    
    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1), 
                    np.array(f1_scores[cls]) - std_devs[cls], 
                    np.array(f1_scores[cls]) + std_devs[cls], 
                    color=colors[cls], alpha=0.1)

# 标注轴标签
ax.set_xlabel("Iteration", fontsize=14)
ax.set_ylabel("F1 Score (%)", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签


# 添加每个类别的虚线
ax.axhline(y=supervise_acc[-1]*100, 
           color='grey', linestyle="--", label=labels[4], linewidth=1.5)

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
ax.set_ylim(75, 95)
# 添加图例
ax.legend(frameon=False)

# 保存高清图片
output_path_lines = "F1_activelearning_iter20.png"
plt.savefig(output_path_lines, bbox_inches="tight", dpi=300)

# 显示图表
plt.show()

# %%
supervise_acc[20]
# Out:
# 0.9401076716016151

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# 重新生成数据
# np.random.seed(42)
num_iterations = 20
num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1, 2, 3, 4]  # 5 个类别

# # 生成预测和真实标签
# entropy_pred_label_lists = [np.random.choice(classes, num_samples, p=[0.25, 0.25, 0.2, 0.15, 0.15]) for _ in range(num_iterations)]
# entropy_true_label_lists = [np.random.choice(classes, num_samples, p=[0.25, 0.25, 0.2, 0.15, 0.15]) for _ in range(num_iterations)]

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    y_pred = entropy_pred_label_lists[i]
    y_true = entropy_true_label_lists[i]

    for cls in classes:
        if cls in y_true:  # 确保类别存在
            f1 = f1_score(y_true, y_pred, labels=[cls], average="macro", zero_division=0)
        else:
            f1 = 0.0  # 避免计算错误
        f1_scores[cls].append(f1*100)

# 计算标准误差（SEM）
std_devs = {cls: np.std(f1_scores[cls]) / np.sqrt(len(f1_scores[cls]) + 1e-9) for cls in f1_scores}

# 画图
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
}

labels = labeldict_findstr

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls], 
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)
    
    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1), 
                    np.array(f1_scores[cls]) - std_devs[cls], 
                    np.array(f1_scores[cls]) + std_devs[cls], 
                    color=colors[cls], alpha=0.1)

# 标注轴标签
ax.set_xlabel("Iteration", fontsize=14)
ax.set_ylabel("F1 Score (%)", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签


# 设置Y轴范围
ax.set_ylim(0, 100)

f1_scores_supervised = {cls: [] for cls in classes}  # 每个类别的 F1-score
for i in range(num_iterations):
    y_pred = supervise_pred_label_lists[i]
    y_true = supervise_true_label_lists[i]

    for cls in classes:
        if cls in y_true:  # 确保类别存在
            f1 = f1_score(y_true, y_pred, labels=[cls], average="macro", zero_division=0)
        else:
            f1 = 0.0  # 避免计算错误
        f1_scores_supervised[cls].append(f1*100)
        
# 添加每个类别的虚线
for cls in f1_scores_supervised:
    ax.axhline(y=f1_scores_supervised[cls][-1], color=colors[cls], linestyle="--", linewidth=1.5)

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)

# 添加图例
ax.legend(frameon=False)

# 保存高清图片
output_path_lines = "F1_everyActivity_with_dashed_supervised1.png"
plt.savefig(output_path_lines, bbox_inches="tight", dpi=300)

# 显示图表
plt.show()

# %% [markdown]
# # cluster 结果对比

# %%
num_iterations = 20
num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            # f1 = base_acc[i]
            f1 = entropy_nmi_list[i]
            f2 = entropy_nmi_list5[i]
            f3 = entropy_nmi_list2[i]
            f4 = entropy_nmi_list1[i]
            # f5 = entropy_acc_wocontrast2[i]
            f6 = entropy_nmi_list2025[i]
            # f7 = entropy_acc_wocontrast500[i]
            avg_f = np.average([f1,f2,f3,f4,f6])
            sem_f = np.std([f1,f2,f3,f4,f6]) / np.sqrt(7 + 1e-9)
        else:
            f1 = entropy_wocont_nmi_list[i]
            f2 = entropy_wocont_nmi_list10[i]
            f3 = entropy_wocont_nmi_list5[i]
            f4 = entropy_wocont_nmi_list50[i]
            # f5 = entropy_acc10[i]
            f6 = entropy_wocont_nmi_list100[i]
            avg_f = np.average([f1,f2,f3,f4,f6])
            sem_f = np.std([f1,f2,f3,f4,f6]) / np.sqrt(7 + 1e-9)
        f1_scores[cls].append(avg_f)
        std_devs[cls].append(sem_f)

# # 计算标准误差（SEM）
# std_devs = {cls: np.std(f1_scores[cls]) / np.sqrt(len(f1_scores[cls]) + 1e-9) for cls in f1_scores}

# 画图
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
}

labels = {0: 'Entropy-based Active Learning', 
          1: 'Entropy Active W/O Contrastive Learning', 
          2: 'OverSampling Active', 
          3: 'Entropy Active',
          4: 'Supervised Baseline'}

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls], 
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)
    
    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1), 
                    np.array(f1_scores[cls]) - std_devs[cls], 
                    np.array(f1_scores[cls]) + std_devs[cls], 
                    color=colors[cls], alpha=0.1)

# 标注轴标签
ax.set_xlabel("Iteration", fontsize=14)
ax.set_ylabel("Normalized Mutual Information", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签


# # 添加每个类别的虚线
# ax.axhline(y=supervise_acc[-1]*100, 
#            color='grey', linestyle="--", label=labels[4], linewidth=1.5)

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
# ax.set_ylim(75, 95)
# 添加图例
ax.legend(frameon=False)

# 保存高清图片
output_path_lines = "clusterresult_contrast.png"
plt.savefig(output_path_lines, bbox_inches="tight", dpi=300)

# 显示图表
plt.show()

# %% [markdown]
# # active learning sample数量对比

# %%
sum_count_dict = {key: 0 for key in labeldict_findstr}
low_array = []
for i in range(len(entropy_selected_labels_list)):
    my_list = entropy_selected_labels_list[i]
    my_list = majority_value(my_list)
    unique, counts = np.unique(my_list, return_counts=True)
    count_dict = dict(zip(unique, counts))

    for key in sum_count_dict:
        sum_count_dict[key] += count_dict.get(key, 0)  # 如果 key 不存在，返回 0
    low_array.append(sum_count_dict.copy())
    
lowdf = pd.DataFrame.from_records(low_array)
# 创建全零的新行（列数与 lowdf 一致）
zero_row = pd.DataFrame(np.zeros((1, lowdf.shape[1])), columns=lowdf.columns)
# 在 DataFrame 末尾添加新行
lowdf = pd.concat([lowdf, zero_row], ignore_index=True)

lower_array = lowdf.to_numpy()

# %%
sum_count_dict = {key: 0 for key in labeldict_findstr}
upper_array = []
for i in range(len(base_selected_labels_list)):
    my_list = base_selected_labels_list[i]
    my_list = majority_value(my_list)
    unique, counts = np.unique(my_list, return_counts=True)
    count_dict = dict(zip(unique, counts))

    for key in sum_count_dict:
        sum_count_dict[key] += count_dict.get(key, 0)  # 如果 key 不存在，返回 0
    upper_array.append(sum_count_dict.copy())
    

# 最后一次迭代，使用全部train data
my_list = supervise_selected_labels_list[-1]
my_list = majority_value(my_list)
unique, counts = np.unique(my_list, return_counts=True)
count_dict = dict(zip(unique, counts))
for key in sum_count_dict:
    sum_count_dict[key] += count_dict.get(key, 0)  # 如果 key 不存在，返回 0
upper_array.append(sum_count_dict.copy())
    
updf = pd.DataFrame.from_records(upper_array)
upper_array = updf.to_numpy()

# %%
# 生成模拟数据
# np.random.seed(42)
num_iterations = 21  # 迭代次数
num_categories = len(labeldict_findstr.keys())  # 代表不同颜色的activity
categories = list(labeldict_findstr.values())



# X 轴的所有迭代点，包括 "Full"
# full_iterations = list(range(1, num_iterations )) + ["Full"]

# 画图
fig, axes = plt.subplots(2, 1, figsize=(6, 4), sharex=True, gridspec_kw={'height_ratios': [1, 1]})


# 绘制上部分的柱状图
bottom = np.zeros(num_iterations)
for i in range(num_categories):
    axes[0].bar(range(num_iterations), lower_array[:, i], color=colors[i], label=categories[i], bottom=bottom)
    bottom += lower_array[:, i]

# 绘制下部分的柱状图
bottom = np.zeros(num_iterations)
for i in range(num_categories):
    axes[1].bar(range(num_iterations), upper_array[:, i], color=colors[i], bottom=bottom)
    bottom += upper_array[:, i]

# 去掉上部分图的x轴刻度
axes[0].tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# 设置X轴刻度和标签
xtick_labels = [str(i) for i in range(1, num_iterations)] + ["Full"]
axes[1].set_xticks(range(num_iterations))
axes[1].set_xticklabels(xtick_labels, rotation=0)

# 设置标签
axes[1].set_xlabel("Iteration no.", fontsize=12)
# axes[0].set_ylabel("Samples", fontsize=12)
# axes[1].set_ylabel("Samples", fontsize=12)
fig.text(0.00, 0.55, "Samples", va='center', rotation=90, fontsize=12)

# 添加网格
for ax in axes:
    ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")

# 添加图例
axes[0].legend(frameon=False, loc="upper left", fontsize=10)

# 调整布局
plt.tight_layout()

# 保存图片
output_path_full = "entropy2supervised_bar_chart.png"
plt.savefig(output_path_full, bbox_inches="tight", dpi=300)

# 显示图表
plt.show()

# %% [markdown]
# # 新数据的F1 score，random seed有五个 - micro F1 score

# %%
# fig2的几个active learning比较

# active learning采用random sampling方法
base_acc = []
base_pred_label_lists, base_true_label_lists, base_selected_labels_list = [], [], []
base_ari_list, base_nmi_list, base_fmi_list = [], [], []
base_silhouette_list, base_label_data_list, base_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__random_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    base_acc.append(result_dict['test_micro_f1_list'])


entropy_acc = []
entropy_pred_label_lists, entropy_true_label_lists, entropy_selected_labels_list = [], [], []
entropy_ari_list, entropy_nmi_list, entropy_fmi_list = [], [], []
entropy_silhouette_list, entropy_label_data_list, entropy_unlabel_data_list = [], [], []
# for sid in [30,31,32,33,34]:
for sid in [30,31,34,38,32]:
# for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__entropy_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # file_name = 'AccelTemp__entropy_Contrast1_warm15_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    entropy_acc.append(result_dict['test_micro_f1_list'])


underRandom_acc = []
underRandom_pred_label_lists, underRandom_true_label_lists, underRandom_selected_labels_list = [], [], []
underRandom_ari_list, underRandom_nmi_list, underRandom_fmi_list = [], [], []
underRandom_silhouette_list, underRandom_label_data_list, underRandom_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__underRandom_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    underRandom_acc.append(result_dict['test_micro_f1_list'])


overAugment_acc = []
overAugment_pred_label_lists, overAugment_true_label_lists, overAugment_selected_labels_list = [], [], []
overAugment_ari_list, overAugment_nmi_list, overAugment_fmi_list = [], [], []
overAugment_silhouette_list, overAugment_label_data_list, overAugment_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__overAugment_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    overAugment_acc.append(result_dict['test_micro_f1_list'])


# representative sampling
repreSamp_acc = []
repreSamp_pred_label_lists, repreSamp_true_label_lists, repreSamp_selected_labels_list = [], [], []
repreSamp_ari_list, repreSamp_nmi_list, repreSamp_fmi_list = [], [], []
repreSamp_silhouette_list, repreSamp_label_data_list, repreSamp_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__repreSamp_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    repreSamp_acc.append(result_dict['test_micro_f1_list'])
    

entropy1_acc = []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__entropy1_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    entropy1_acc.append(result_dict['test_micro_f1_list'])

entropy2_acc = []
for sid in [1,2,5,10,2025]:
# for sid in [38,37,36,35,34]:
    file_name = 'AccelTemp__entropy2_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    # result_dict = load_data(file_name)
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
    entropy2_acc.append(result_dict['test_micro_f1_list'])

# %%
num_iterations = 20
# num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1, 2, 3, 4, 5, 6]  # 5 个类别
# classes = [0, 1, 2, 3, 4]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            f1scores = []
            for sid in range(5):
                f1scores.append(entropy_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 3:
            f1scores = []
            for sid in range(5):
                f1scores.append(base_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 4:
            f1scores = []
            for sid in range(5):
                f1scores.append(underRandom_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 5:
            f1scores = []
            for sid in range(5):
                f1scores.append(overAugment_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 6:
            f1scores = []
            for sid in range(5):
                f1scores.append(repreSamp_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 1:
            f1scores = []
            for sid in range(5):
                f1scores.append(entropy1_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 2:
            f1scores = []
            for sid in range(5):
                f1scores.append(entropy2_acc[sid][i])
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        else:
            continue
            print('error')


# 画图
# fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
    5: "#FFB74D",  # 橙色 - Category 5
    6: "#9C27B0",  # 紫色 - Category 6
}

labels = {0: 'Entropy Sampling (Proposed)',
    # 0: 'Entropy Sampling',
          3: 'Random Sampling',
          4: 'Under Sampling',
          5: 'Over Sampling',
          6: 'Representative Sampling',
          1: 'Least_confidence Sampling',
          2: 'Min_margin Sampling',
          7: 'Supervised Learning Baseline',
          }

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls],
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)

    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1),
                    np.array(f1_scores[cls]) - std_devs[cls],
                    np.array(f1_scores[cls]) + std_devs[cls],
                    color=colors[cls], alpha=0.1)

# 添加supervised的虚线
file_name = 'AccelTemp__supervisebase_seed2025_epoch49_results.pkl'  # 
result_dict = load_data(file_name)
supervise_acc = result_dict['test_micro_f1_list']
ax.axhline(y=supervise_acc[-1]*100,
           color='grey', linestyle="--", label=labels[7], linewidth=1.5)

# 标注轴标签
ax.set_xlabel("Iteration no.", fontsize=14)
ax.set_ylabel("Weighted Macro F1 Score (%)", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
# ax.set_xticks([1, 5, 10, 15, 20, 25, 30])  # 设置刻度位置
# ax.set_xticklabels(["1", "5", "10", "15", "20", "25", "30"])  # 设置刻度标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
ax.set_ylim(78, 95)
# 添加图例
ax.legend(frameon=False)

plt.show()
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %% [markdown]
# # 新数据的F1 score，random seed有五个 - weighted macro F1 score

# %%
# fig2的几个active learning比较

# active learning采用random sampling方法
base_acc = []
base_pred_label_lists, base_true_label_lists, base_selected_labels_list = [], [], []
base_ari_list, base_nmi_list, base_fmi_list = [], [], []
base_silhouette_list, base_label_data_list, base_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__random_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    base_acc.append(result_dict['test_micro_f1_list'])
    base_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    base_true_label_lists.append(result_dict2['test_truth_label_lists'])


entropy_acc = []
entropy_pred_label_lists, entropy_true_label_lists, entropy_selected_labels_list = [], [], []
entropy_ari_list, entropy_nmi_list, entropy_fmi_list = [], [], []
entropy_silhouette_list, entropy_label_data_list, entropy_unlabel_data_list = [], [], []
# for sid in [30,31,32,33,34]:
# for sid in [30,31,34,38,32]:
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__entropy_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropy_acc.append(result_dict['test_micro_f1_list'])
    entropy_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropy_true_label_lists.append(result_dict2['test_truth_label_lists'])


underRandom_acc = []
underRandom_pred_label_lists, underRandom_true_label_lists, underRandom_selected_labels_list = [], [], []
underRandom_ari_list, underRandom_nmi_list, underRandom_fmi_list = [], [], []
underRandom_silhouette_list, underRandom_label_data_list, underRandom_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__underRandom_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    underRandom_acc.append(result_dict['test_micro_f1_list'])
    underRandom_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    underRandom_true_label_lists.append(result_dict2['test_truth_label_lists'])
    

overAugment_acc = []
overAugment_pred_label_lists, overAugment_true_label_lists, overAugment_selected_labels_list = [], [], []
overAugment_ari_list, overAugment_nmi_list, overAugment_fmi_list = [], [], []
overAugment_silhouette_list, overAugment_label_data_list, overAugment_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__overAugment_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    overAugment_acc.append(result_dict['test_micro_f1_list'])
    overAugment_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    overAugment_true_label_lists.append(result_dict2['test_truth_label_lists'])
    

# representative sampling
repreSamp_acc = []
repreSamp_pred_label_lists, repreSamp_true_label_lists, repreSamp_selected_labels_list = [], [], []
repreSamp_ari_list, repreSamp_nmi_list, repreSamp_fmi_list = [], [], []
repreSamp_silhouette_list, repreSamp_label_data_list, repreSamp_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__repreSamp_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    repreSamp_acc.append(result_dict['test_micro_f1_list'])
    repreSamp_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    repreSamp_true_label_lists.append(result_dict2['test_truth_label_lists'])
    

entropy1_acc = []
entropy1_pred_label_lists, entropy1_true_label_lists, entropy1_selected_labels_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__entropy1_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropy1_acc.append(result_dict['test_micro_f1_list'])
    entropy1_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropy1_true_label_lists.append(result_dict2['test_truth_label_lists'])

entropy2_acc = []
entropy2_pred_label_lists, entropy2_true_label_lists, entropy2_selected_labels_list = [], [], []
for sid in [1,2,5,10,2025]:
# for sid in [38,37,36,35,34]:
    file_name = 'AccelTemp__entropy2_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid  
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropy2_acc.append(result_dict['test_micro_f1_list'])
    entropy2_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropy2_true_label_lists.append(result_dict2['test_truth_label_lists'])

# %%
num_iterations = 20
# num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1, 2, 3, 4, 5, 6]  # 5 个类别
# classes = [0, 1, 2, 3, 4]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy_acc[sid][i])
                y_pred = entropy_pred_label_lists[sid][i]
                y_true = entropy_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)

                f1scores.append(f1)

            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 3:
            f1scores = []
            for sid in range(5):
                # f1scores.append(base_acc[sid][i])
                y_pred = base_pred_label_lists[sid][i]
                y_true = base_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
                
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 4:
            f1scores = []
            for sid in range(5):
                # f1scores.append(underRandom_acc[sid][i])
                y_pred = underRandom_pred_label_lists[sid][i]
                y_true = underRandom_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)

            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 5:
            f1scores = []
            for sid in range(5):
                # f1scores.append(overAugment_acc[sid][i])
                y_pred = overAugment_pred_label_lists[sid][i]
                y_true = overAugment_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
                
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 6:
            f1scores = []
            for sid in range(5):
                # f1scores.append(repreSamp_acc[sid][i])
                y_pred = repreSamp_pred_label_lists[sid][i]
                y_true = repreSamp_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
            
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 1:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy1_acc[sid][i])
                y_pred = entropy1_pred_label_lists[sid][i]
                y_true = entropy1_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
            
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 2:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy2_acc[sid][i])
                y_pred = entropy2_pred_label_lists[sid][i]
                y_true = entropy2_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        else:
            continue
            print('error')


# 画图
# fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
    5: "#FFB74D",  # 橙色 - Category 5
    6: "#9C27B0",  # 紫色 - Category 6
}

labels = {0: 'Entropy Sampling (Proposed)',
    # 0: 'Entropy Sampling',
          3: 'Random Sampling',
          4: 'Under Sampling',
          5: 'Over Sampling',
          6: 'Representative Sampling',
          1: 'Least_confidence Sampling',
          2: 'Min_margin Sampling',
          7: 'Supervised Learning Baseline',
          }

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls],
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)

    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1),
                    np.array(f1_scores[cls]) - std_devs[cls],
                    np.array(f1_scores[cls]) + std_devs[cls],
                    color=colors[cls], alpha=0.1)

# 添加supervised的虚线
file_name = 'AccelTemp__supervisebase_seed2025_epoch49_results.pkl'  # 
result_dict = load_data(file_name)
supervise_acc = result_dict['test_macro_f1_list']

y_pred = result_dict['test_pred_label_lists']
y_true = result_dict['test_truth_label_lists']
f1 = f1_score(y_true[-1], y_pred[-1], average="weighted", zero_division=0)

ax.axhline(y=f1*100,
           color='grey', linestyle="--", label=labels[7], linewidth=1.5)

# 标注轴标签
ax.set_xlabel("Iteration no.", fontsize=14)
ax.set_ylabel("Weighted Macro F1 Score (%)", fontsize=14)
# ax.set_xticklabels([])  # 隐藏 X 轴标签
# ax.set_xticks([1, 5, 10, 15, 20, 25, 30])  # 设置刻度位置
# ax.set_xticklabels(["1", "5", "10", "15", "20", "25", "30"])  # 设置刻度标签
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
ax.set_ylim(77, 95)
# 添加图例
ax.legend(frameon=False)

plt.show()
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
len(y_pred[0])
# Out:
# 1486

# %%
num_iterations = 20
# num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1, 2, 3, 4, 5, 6]  # 5 个类别
# classes = [0, 1, 2, 3, 4]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy_acc[sid][i])
                y_pred = entropy_pred_label_lists[sid][i]
                y_true = entropy_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)

                f1scores.append(f1)

            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 3:
            f1scores = []
            for sid in range(5):
                # f1scores.append(base_acc[sid][i])
                y_pred = base_pred_label_lists[sid][i]
                y_true = base_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)
                
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 4:
            f1scores = []
            for sid in range(5):
                # f1scores.append(underRandom_acc[sid][i])
                y_pred = underRandom_pred_label_lists[sid][i]
                y_true = underRandom_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)

            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 5:
            f1scores = []
            for sid in range(5):
                # f1scores.append(overAugment_acc[sid][i])
                y_pred = overAugment_pred_label_lists[sid][i]
                y_true = overAugment_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)
                
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        elif cls == 6:
            f1scores = []
            for sid in range(5):
                # f1scores.append(repreSamp_acc[sid][i])
                y_pred = repreSamp_pred_label_lists[sid][i]
                y_true = repreSamp_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)
            
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 1:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy1_acc[sid][i])
                y_pred = entropy1_pred_label_lists[sid][i]
                y_true = entropy1_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)
            
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 2:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropy2_acc[sid][i])
                y_pred = entropy2_pred_label_lists[sid][i]
                y_true = entropy2_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="macro", zero_division=0)
                f1scores.append(f1)
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        else:
            continue
            print('error')


# 画图
# fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
    5: "#FFB74D",  # 橙色 - Category 5
    6: "#9C27B0",  # 紫色 - Category 6
}

labels = {0: 'Entropy Sampling (Proposed)',
    # 0: 'Entropy Sampling',
          3: 'Random Sampling',
          4: 'Under Sampling',
          5: 'Over Sampling',
          6: 'Representative Sampling',
          1: 'Least_confidence Sampling',
          2: 'Min_margin Sampling',
          7: 'Supervised Learning Baseline',
          }

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls],
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)

    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1),
                    np.array(f1_scores[cls]) - std_devs[cls],
                    np.array(f1_scores[cls]) + std_devs[cls],
                    color=colors[cls], alpha=0.1)

# 添加supervised的虚线
file_name = 'AccelTemp__supervisebase_seed2025_epoch49_results.pkl'  # 
result_dict = load_data(file_name)
supervise_acc = result_dict['test_macro_f1_list']

y_pred = result_dict['test_pred_label_lists']
y_true = result_dict['test_truth_label_lists']
f1 = f1_score(y_true[-1], y_pred[-1], average="macro", zero_division=0)

ax.axhline(y=f1*100,
           color='grey', linestyle="--", label=labels[7], linewidth=1.5)

# 标注轴标签
ax.set_xlabel("Iteration no.", fontsize=18, fontweight='bold')
ax.set_ylabel("Macro F1 Score (%)", fontsize=18, fontweight='bold')
ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"], fontsize=18)  # 设置刻度标签

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
# ax.set_ylim(50, 89)
yticks = list(range(50, 91, 5))
ax.set_yticks(yticks)  # 应用刻度位置
# 设置 y 轴刻度标签
plt.gca().set_yticklabels([str(a) for a in yticks], fontsize=16)
# 添加图例
ax.legend(frameon=False, ncol=1, fontsize=16)

plt.show()
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
cls
# Out:
# 0

# %% [markdown]
# # 重新计算fig3（a），w/o Contrastive learning结果

# %%
# # 完全不使用contrastive learning的entropy active learning
# file_name = 'AccelTemp__entropy_Contrast1_warm0_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict = load_data(file_name)
# entropy_acc_wocontrast = result_dict['test_micro_f1_list']
# print(entropy_acc_wocontrast[-1])
# entropy_wocont_ari_list = result_dict['ari_list']
# entropy_wocont_nmi_list = result_dict['nmi_list']
# entropy_wocont_fmi_list = result_dict['fmi_list']
# entropy_wocont_silhouette_list = result_dict['silhouette_list']
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed10_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict10 = load_data(file_name)
# entropy_acc_wocontrast10 = result_dict10['test_micro_f1_list']
# print(entropy_acc_wocontrast10[-1])
# entropy_wocont_ari_list10 = result_dict10['ari_list']
# entropy_wocont_nmi_list10 = result_dict10['nmi_list']
# entropy_wocont_fmi_list10 = result_dict10['fmi_list']
# entropy_wocont_silhouette_list10 = result_dict10['silhouette_list']
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed5_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict5 = load_data(file_name)
# entropy_acc_wocontrast5 = result_dict5['test_micro_f1_list']
# print(entropy_acc_wocontrast5[-1])
# entropy_wocont_ari_list5 = result_dict5['ari_list']
# entropy_wocont_nmi_list5 = result_dict5['nmi_list']
# entropy_wocont_fmi_list5 = result_dict5['fmi_list']
# entropy_wocont_silhouette_list5 = result_dict5['silhouette_list']
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed50_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict50 = load_data(file_name)
# entropy_acc_wocontrast50 = result_dict50['test_micro_f1_list']
# print(entropy_acc_wocontrast50[-1])
# entropy_wocont_ari_list50 = result_dict50['ari_list']
# entropy_wocont_nmi_list50 = result_dict50['nmi_list']
# entropy_wocont_fmi_list50 = result_dict50['fmi_list']
# entropy_wocont_silhouette_list50 = result_dict50['silhouette_list']
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed2_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict2 = load_data(file_name)
# entropy_acc_wocontrast2 = result_dict2['test_micro_f1_list']
# print(entropy_acc_wocontrast2[-1])
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed100_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict100 = load_data(file_name)
# entropy_acc_wocontrast100 = result_dict100['test_micro_f1_list']
# print(entropy_acc_wocontrast100[-1])
# entropy_wocont_ari_list100 = result_dict100['ari_list']
# entropy_wocont_nmi_list100 = result_dict100['nmi_list']
# entropy_wocont_fmi_list100 = result_dict100['fmi_list']
# entropy_wocont_silhouette_list100 = result_dict100['silhouette_list']
# 
# file_name = 'AccelTemp__entropy_Contrast1_warm0_seed500_epoch20_results.pkl'  # noSupCont, only entropy active learning
# result_dict500 = load_data(file_name)
# entropy_acc_wocontrast500 = result_dict500['test_micro_f1_list']
# print(entropy_acc_wocontrast500[-1])
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))
# ...

# %%
entropyt_acc = []
entropy_pred_label_lists, entropy_true_label_lists = [], []
for sid in [1,2,5,10,2025]:
# for sid in [30,31,34,38,32]:
    # sid2 = sid + 30
    file_name = 'AccelTemp__entropy_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid 
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropy_acc.append(result_dict['test_micro_f1_list'])
    entropy_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropy_true_label_lists.append(result_dict2['test_truth_label_lists'])

# %%
entropytt_acc = []
entropytt_pred_label_lists, entropytt_true_label_lists = [], []
for sid in [32,31,35,37,33]:
# for sid in [1,2,5,10,2025]:
    # sid2 = sid + 30
    file_name = 'AccelTemp__entropy_Contrast1_warm0_seed%d_epoch20_results.pkl'%sid
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropytt_acc.append(result_dict['test_micro_f1_list'])
    entropytt_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropytt_true_label_lists.append(result_dict2['test_truth_label_lists'])
    # print(tmp[8])
    # entropytt_acc.append(tmp)

# %%
num_iterations = 20
# num_samples = 100  # 每次迭代预测的样本数
classes = [0, 1]  # 5 个类别
# classes = [0, 1, 2, 3, 4]  # 5 个类别

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score

for i in range(num_iterations):
    for cls in classes:
        if cls == 0:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropyt_acc[sid][i])
                y_pred = entropy_pred_label_lists[sid][i]
                y_true = entropy_true_label_lists[sid][i]
                f1 = f1_score(y_true[0], y_pred[0], average="weighted", zero_division=0)
                f1scores.append(f1)
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        if cls == 1:
            f1scores = []
            for sid in range(5):
                # f1scores.append(entropytt_acc[sid][i])
                y_pred = entropytt_pred_label_lists[sid][i]
                y_true = entropytt_true_label_lists[sid][i]
                f1 = f1_score(y_true, y_pred, average="weighted", zero_division=0)
                f1scores.append(f1)
            avg_f = np.average(f1scores)
            sem_f = np.std(f1scores) / np.sqrt(len(f1scores) + 1e-9)
            f1_scores[cls].append(avg_f * 100)
            std_devs[cls].append(sem_f * 100)
        else:
            continue
            print('error')


# 画图
fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
# fig, ax = plt.subplots(figsize=(6, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
    5: "#FFB74D",  # 橙色 - Category 5
    6: "#9C27B0",  # 紫色 - Category 6
}

labels = {0: 'Proposed Method (Entropy Sampling)', 
          1: 'Proposed W/O Contrastive Learning', 
          }

# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls],
            color=colors[cls], linestyle="-", label=labels[cls], linewidth=2)

    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1),
                    np.array(f1_scores[cls]) - std_devs[cls],
                    np.array(f1_scores[cls]) + std_devs[cls],
                    color=colors[cls], alpha=0.1)

# # 添加supervised的虚线
# file_name = 'AccelTemp__supervisebase_seed2025_epoch49_results.pkl'  # 
# result_dict = load_data(file_name)
# supervise_acc = result_dict['test_micro_f1_list']
# ax.axhline(y=supervise_acc[-1]*100,
#            color='grey', linestyle="--", label=labels[1], linewidth=1.5)

# 标注轴标签
ax.set_xlabel("Iteration no.", fontsize=14)
ax.set_ylabel("F1 Score (%)", fontsize=14)

ax.set_xticks([1, 5, 10, 15, 20])  # 设置刻度位置
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签

# 网格线优化
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")
ax.set_xlim(1, num_iterations)
ax.set_ylim(74, 95)
# 添加图例
ax.legend(frameon=False)

plt.show()

# %% [markdown]
# # entropy 和supervised learning的每个class的对比

# %%
entropy_acc = []
entropy_pred_label_lists, entropy_true_label_lists, entropy_selected_labels_list = [], [], []
entropy_ari_list, entropy_nmi_list, entropy_fmi_list = [], [], []
entropy_silhouette_list, entropy_label_data_list, entropy_unlabel_data_list = [], [], []
for sid in [1,2,5,10,2025]:
    file_name = 'AccelTemp__entropy_Contrast1_warm20_seed%d_epoch20_results.pkl'%sid 
    with open(os.path.join(root_path, file_name), 'rb') as f:
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        pickle.load(f)
        result_dict = pickle.load(f)
        result_dict1 = pickle.load(f)
        result_dict2 = pickle.load(f)
    entropy_acc.append(result_dict['test_micro_f1_list'])
    entropy_pred_label_lists.append(result_dict1['test_pred_label_lists'])
    entropy_true_label_lists.append(result_dict2['test_truth_label_lists'])

num_iterations = 20
classes = [0, 1, 2, 3, 4]  # 5 个类别

labels = labeldict_findstr

# 计算 F1 Score
f1_scores = {cls: [] for cls in classes}  # 每个类别的 F1-score
std_devs = {cls: [] for cls in classes}  # 每个类别的 F1-score
for i in range(num_iterations):
    for cls in classes: # number of classes
        tmpscore = []
        for sid in range(5):  # random seeds
            y_pred = entropy_pred_label_lists[sid][i][0]
            y_true = entropy_true_label_lists[sid][i][0]
            if cls in y_true:  # 确保类别存在
                f1 = f1_score(y_true, y_pred, labels=[cls], average="weighted", zero_division=0)
            else:
                f1 = 0.0  # 避免计算错误
            tmpscore.append(f1)
        avg_f = np.average(tmpscore)
        sem_f = np.std(tmpscore) / np.sqrt(len(tmpscore) + 1e-9)
        f1_scores[cls].append(avg_f * 100)
        std_devs[cls].append(sem_f * 100)

# %%
# 添加supervised的虚线
file_name = 'AccelTemp__supervisebase_seed2025_epoch49_results.pkl'  # 
result_dict = load_data(file_name)
# supervise_acc = result_dict['test_micro_f1_list']

supervise_pred = result_dict['test_pred_label_lists']
supervise_true = result_dict['test_truth_label_lists']
# supervise_acc = f1_score(y_true, y_pred, labels=[cls], average="macro", zero_division=0)

# 计算 F1 Score
f1_scores2 = {cls: [] for cls in classes}  # 每个类别的 F1-score
for i in range(1):
    for cls in classes: # number of classes
        y_pred = supervise_pred[-1]
        y_true = supervise_true[-1]
        if cls in y_true:  # 确保类别存在
            f1 = f1_score(y_true, y_pred, labels=[cls], average="weighted", zero_division=0)
        else:
            f1 = 0.0  # 避免计算错误
        f1_scores2[cls].append(f1 * 100)
# Out:
# D:\Users\dell\anaconda3\envs\deepviewbackup\lib\site-packages\torch\storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
# fig, ax = plt.subplots(figsize=(5, 5), dpi=300)
fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

# 颜色匹配图例
colors = {
    0: "#5470C6",  # 深蓝 - Attack
    1: "#91CC75",  # 绿色 - Investigation
    2: "#FAC858",  # 金黄 - Mount
    3: "#EE6666",  # 红色 - Category 3
    4: "#73C0DE",  # 天蓝 - Category 4
    5: "#FFB74D",  # 橙色 - Category 5
    6: "#9C27B0",  # 紫色 - Category 6
}


# 绘制每个类别的曲线
for cls in f1_scores:
    ax.plot(range(1, num_iterations + 1), f1_scores[cls],
            color=colors[cls], linestyle="-", label=labels[cls]+str(' (Entropy)'), linewidth=2)
    # 添加标准误差的阴影区域
    ax.fill_between(range(1, num_iterations + 1),
                    np.array(f1_scores[cls]) - std_devs[cls],
                    np.array(f1_scores[cls]) + std_devs[cls],
                    color=colors[cls], alpha=0.15)
    
for cls in f1_scores2:    
    ax.axhline(y=f1_scores2[cls][-1],
               color=colors[cls], linestyle="--", label=labels[cls]+str(' (Supervised)'), linewidth=1.5)

# for cls in f1_scores2:
#     ax.plot(range(1, num_iterations + 1), f1_scores2[cls],
#             color=colors[cls], linestyle="--", label=labels[cls]+str(' (Supervised)'), linewidth=1.5)
    # # 添加标准误差的阴影区域
    # ax.fill_between(range(1, num_iterations + 1),
    #                 np.array(f1_scores2[cls]) - std_devs2[cls],
    #                 np.array(f1_scores2[cls]) + std_devs2[cls],
    #                 color=colors[cls], alpha=0.08)
    
# 图表美化
ax.set_xlabel("Iteration no.", fontsize=14)
ax.set_ylabel("F1 Score (%)", fontsize=14)
ax.set_xticks([1, 5, 10, 15, 20])
ax.set_xticklabels(["1", "5", "10", "15", "20"])  # 设置刻度标签
ax.set_xlim(1, num_iterations)
ax.set_ylim(18, 100)
ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.7, color="gray")

# 图例美化
ax.legend(frameon=False, fontsize=10, ncol=2)
plt.tight_layout()
