# %%
import os
import pickle
import pandas as pd
datap = 'CollectedData_v.pkl'
datapn =  'CollectedData_v_new.pkl'
with open(datap, 'rb') as f:
    data = pd.read_pickle(f)
with open(datapn, 'rb') as f:
    data_new = pd.read_pickle(f)

# %%
data_new[0][0].shape
# Out:
# (49973, 90, 3)

# %%
import matplotlib.pyplot as plt
plt.plot(data_new[0][0][1,:,:])
plt.show()

# %%
plt.plot(data[0][0][2,:,:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.head(10)
# Out:
#   logger_id animal_tag               timestamp     acc_x     acc_y     acc_z  \
# 0   lbs0004       LB09 2022-05-17 09:10:01.000  1.384558  0.171796  0.408291
# 0   lbs0003       LB08 2022-05-17 09:04:01.000  0.267622 -0.647721  0.102985
# 1   lbs0004       LB09 2022-05-17 09:10:01.032  1.384558  0.171796  0.391214
# 1   lbs0003       LB08 2022-05-17 09:04:01.032  0.267622 -0.647721  0.102985
# 2   lbs0004       LB09 2022-05-17 09:10:01.064  1.384558  0.171796  0.408291
# 2   lbs0003       LB08 2022-05-17 09:04:01.064  0.253834 -0.647721  0.102985
# 3   lbs0004       LB09 2022-05-17 09:10:01.096  1.384558  0.171796  0.408291
# 3   lbs0003       LB08 2022-05-17 09:04:01.096  0.267622 -0.663740  0.102985
# 4   lbs0004       LB09 2022-05-17 09:10:01.129  1.384558  0.171796  0.408291
# 4   lbs0003       LB08 2022-05-17 09:04:01.129  0.267622 -0.647721  0.102985
#
#    latitude  longitude  gyro_x  gyro_y  ...  illumination     pressure  \
# ...

# %%
a = data[['gyro_x']].dropna()
plt.plot(a)
plt.show()

# %%
len(a)
# Out:
# 0

# %%
plt.plot(data[['acc_x']].values[:300])
plt.show()
